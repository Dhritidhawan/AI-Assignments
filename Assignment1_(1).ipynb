# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhritidhawan/AI-Assignments/blob/main/Assignment1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assingment 1.1: WAP to print your name three times

# %%
print("Dhriti Dhawan")
print("Dhriti Dhawan")
print("Dhriti Dhawan")

# %% [markdown]
# Assignent 2.1 : WAP to add three numbers and print the result.

# %%
a = 60
b = 20
c = 100
sum = a + b + c
print(a, "+" ,b, "+" ,c, "-->" ,sum)

# %% [markdown]
# Assignment 2.2 : WAP to concatinate three strings and print the result.

# %%
str1 = "AI"
str2 = "for"
str3 = "Engineers"
result = str1 + " "+ str2 + " "+ str3
print("Concatinated string:",result)

# %% [markdown]
# Assignment 4.1 : WAP to print the table of 7,9.

# %%
print("Table of 7 : ")
for i in range(1,11):
    print(7," * ",i," = ",i * 7)
print("\nTable of 9 :")
for i in range(1,11):
    print(9," * ",i," = ",i*9)

# %% [markdown]
# Assignment 4.2 : WAP to print the table of n and n is given by user.

# %%
n = int(input("Enter a number :"))
for i in range(1,11) :
  print(n, " * ",i, " = ",i*n)

# %% [markdown]
# Assingment 4.3: WAP to add all the numbers from 1 to n and n is given by user.

# %%
n = int(input("Enter a number : "))
s=0
for i in range(1,n+1):
    s=s+i
print("Sum is --> ",s)

# %% [markdown]
# Assingment 5.1: WAP to find max amoung three numbers and input from user. [Try max() function]

# %%
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = int(input("Enter third number : "))
maximum = max(a,b,c)
print("The maximum number is :",maximum)

# %% [markdown]
# Assingment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.

# %%
n= int(input("Enter the value of n : "))
s=0
for i in range(1,n+1):
  if i % 7 == 0 and i % 9 ==0 :
    s = s + i
print("Sum of numbers divisible by 7 and 9 from 1 to",n, "is:",s)

# %% [markdown]
# Assingment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.

# %%
n = int(input("Enter a no:"))
s=0
for num in range(2,n+1):
  count = 0
  for i in range(1,num+1):
    if num % i == 0:
      count = count + 1
  if count == 2:
    s = s + num
print("Sum of prime numbers from 1 to",n,"is:",s)

# %% [markdown]
# Assingment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.

# %%
def sum_of_odds(n):
  s=0
  for i in range(1,n+1):
    if i%2 != 0 :
      s = s+i
  return s
n = int(input("Enter a no:"))
print("Sum of odd numbers from 1 to",n,"is:",sum_of_odds(n))

# %% [markdown]
# Assingment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user.

# %%
def sum_of_primes(n):
    s=0
    for num in range(2,n+1):
       count = 0
       for i in range(1,num+1):
           if num % i == 0:
              count = count + 1
       if count == 2:
               s = s + num
    return s
n = int(input("Enter the value of n: "))
print("Sum of prime numbers from 1 to",n," is ",sum_of_primes(n))
